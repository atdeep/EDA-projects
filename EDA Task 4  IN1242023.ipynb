# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import matplotlib.colors as mcolors 
import datetime as dt
import seaborn as sns
from scipy import stats

# %%
df = pd.read_csv(r"C:\Users\bunty\Downloads\data.xlsx - Sheet1.csv")

df
# Out:
#      Unnamed: 0      ID     Salary           DOJ           DOL  \
# 0         train  203097   420000.0   6/1/12 0:00       present
# 1         train  579905   500000.0   9/1/13 0:00       present
# 2         train  810601   325000.0   6/1/14 0:00       present
# 3         train  267447  1100000.0   7/1/11 0:00       present
# 4         train  343523   200000.0   3/1/14 0:00   3/1/15 0:00
# ...         ...     ...        ...           ...           ...
# 3993      train   47916   280000.0  10/1/11 0:00  10/1/12 0:00
# 3994      train  752781   100000.0   7/1/13 0:00   7/1/13 0:00
# 3995      train  355888   320000.0   7/1/13 0:00       present
# 3996      train  947111   200000.0   7/1/14 0:00   1/1/15 0:00
# 3997      train  324966   400000.0   2/1/13 0:00       present
#
#                       Designation           JobCity Gender           DOB  \
# 0         senior quality engineer         Bangalore      f  2/19/90 0:00
# 1               assistant manager            Indore      m  10/4/89 0:00
# 2                systems engineer           Chennai      f   8/3/92 0:00
# 3        senior software engineer           Gurgaon      m  12/5/89 0:00
# 4                             get           Manesar      m  2/27/91 0:00
# ...                           ...               ...    ...           ...
# 3993            software engineer        New Delhi       m  4/15/87 0:00
# 3994             technical writer         Hyderabad      f  8/27/92 0:00
# 3995  associate software engineer         Bangalore      m   7/3/91 0:00
# 3996           software developer  Asifabadbanglore      f  3/20/92 0:00
# 3997      senior systems engineer           Chennai      f  2/26/91 0:00
#
#       10percentage  ... ComputerScience  MechanicalEngg  ElectricalEngg  \
# 0            84.30  ...              -1              -1              -1
# 1            85.40  ...              -1              -1              -1
# 2            85.00  ...              -1              -1              -1
# 3            85.60  ...              -1              -1              -1
# 4            78.00  ...              -1              -1              -1
# ...            ...  ...             ...             ...             ...
# 3993         52.09  ...              -1              -1              -1
# 3994         90.00  ...              -1              -1              -1
# 3995         81.86  ...              -1              -1              -1
# 3996         78.72  ...             438              -1              -1
# 3997         70.60  ...              -1              -1              -1
#
#      TelecomEngg  CivilEngg  conscientiousness agreeableness extraversion  \
# 0             -1         -1             0.9737        0.8128       0.5269
# 1             -1         -1            -0.7335        0.3789       1.2396
# 2             -1         -1             0.2718        1.7109       0.1637
# 3             -1         -1             0.0464        0.3448      -0.3440
# 4             -1         -1            -0.8810       -0.2793      -1.0697
# ...          ...        ...                ...           ...          ...
# 3993          -1         -1            -0.1082        0.3448       0.2366
# 3994          -1         -1            -0.3027        0.8784       0.9322
# 3995          -1         -1            -1.5765       -1.5273      -1.5051
# 3996          -1         -1            -0.1590        0.0459      -0.4511
# 3997          -1         -1            -1.1128       -0.2793      -0.6343
#
#       nueroticism  openess_to_experience
# 0         1.35490                -0.4455
# 1        -0.10760                 0.8637
# 2        -0.86820                 0.6721
# 3        -0.40780                -0.9194
# 4         0.09163                -0.1295
# ...           ...                    ...
# 3993      0.64980                -0.9194
# 3994      0.77980                -0.0943
# 3995     -1.31840                -0.7615
# 3996     -0.36120                -0.0943
# 3997      1.32553                -0.6035
#
# [3998 rows x 39 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3998 entries, 0 to 3997
# Data columns (total 39 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             3998 non-null   object
#  1   ID                     3998 non-null   int64
#  2   Salary                 3998 non-null   float64
#  3   DOJ                    3998 non-null   object
#  4   DOL                    3998 non-null   object
#  5   Designation            3998 non-null   object
#  6   JobCity                3998 non-null   object
#  7   Gender                 3998 non-null   object
#  8   DOB                    3998 non-null   object
#  9   10percentage           3998 non-null   float64
#  10  10board                3998 non-null   object
#  11  12graduation           3998 non-null   int64
#  12  12percentage           3998 non-null   float64
#  13  12board                3998 non-null   object
#  14  CollegeID              3998 non-null   int64
#  15  CollegeTier            3998 non-null   int64
#  16  Degree                 3998 non-null   object
#  17  Specialization         3998 non-null   object
#  18  collegeGPA             3998 non-null   float64
#  19  CollegeCityID          3998 non-null   int64
#  20  CollegeCityTier        3998 non-null   int64
#  21  CollegeState           3998 non-null   object
#  22  GraduationYear         3998 non-null   int64
#  23  English                3998 non-null   int64
#  24  Logical                3998 non-null   int64
#  25  Quant                  3998 non-null   int64
#  26  Domain                 3998 non-null   float64
#  27  ComputerProgramming    3998 non-null   int64
#  28  ElectronicsAndSemicon  3998 non-null   int64
#  29  ComputerScience        3998 non-null   int64
#  30  MechanicalEngg         3998 non-null   int64
#  31  ElectricalEngg         3998 non-null   int64
#  32  TelecomEngg            3998 non-null   int64
#  33  CivilEngg              3998 non-null   int64
#  34  conscientiousness      3998 non-null   float64
#  35  agreeableness          3998 non-null   float64
#  36  extraversion           3998 non-null   float64
#  37  nueroticism            3998 non-null   float64
#  38  openess_to_experience  3998 non-null   float64
# dtypes: float64(10), int64(17), object(12)
# memory usage: 1.2+ MB

# %%
#What is the avg time, salary worked of employees who left the company?

time_worked_df = df[df["DOL"] != "present"]

time_worked_df
# Out:
#      Unnamed: 0      ID    Salary           DOJ           DOL  \
# 4         train  343523  200000.0   3/1/14 0:00   3/1/15 0:00
# 6         train  947847  300000.0   8/1/14 0:00   5/1/15 0:00
# 7         train  912934  400000.0   7/1/14 0:00   7/1/15 0:00
# 10        train   87291  600000.0   4/1/11 0:00   4/1/15 0:00
# 11        train  190393  450000.0   8/1/11 0:00  10/1/14 0:00
# ...         ...     ...       ...           ...           ...
# 3991      train  230873  630000.0   7/1/11 0:00  10/1/14 0:00
# 3992      train  344407  800000.0   4/1/14 0:00   4/1/15 0:00
# 3993      train   47916  280000.0  10/1/11 0:00  10/1/12 0:00
# 3994      train  752781  100000.0   7/1/13 0:00   7/1/13 0:00
# 3996      train  947111  200000.0   7/1/14 0:00   1/1/15 0:00
#
#                   Designation           JobCity Gender           DOB  \
# 4                         get           Manesar      m  2/27/91 0:00
# 6      java software engineer          Banglore      m   2/1/93 0:00
# 7         mechanical engineer         Bangalore      m  5/27/92 0:00
# 10       senior php developer         Bangalore      m  6/24/89 0:00
# 11    senior systems engineer              Pune      m  2/10/90 0:00
# ...                       ...               ...    ...           ...
# 3991          systems analyst         Bangalore      m  5/20/90 0:00
# 3992                  manager            Rajkot      m  6/22/90 0:00
# 3993        software engineer        New Delhi       m  4/15/87 0:00
# 3994         technical writer         Hyderabad      f  8/27/92 0:00
# 3996       software developer  Asifabadbanglore      f  3/20/92 0:00
#
#       10percentage  ... ComputerScience  MechanicalEngg  ElectricalEngg  \
# 4            78.00  ...              -1              -1              -1
# 6            86.08  ...             346              -1              -1
# 7            92.00  ...              -1             469              -1
# 10           88.60  ...              -1              -1              -1
# 11           81.00  ...              -1              -1              -1
# ...            ...  ...             ...             ...             ...
# 3991         80.00  ...              -1              -1              -1
# 3992         73.00  ...              -1              -1              -1
# 3993         52.09  ...              -1              -1              -1
# 3994         90.00  ...              -1              -1              -1
# 3996         78.72  ...             438              -1              -1
#
#      TelecomEngg  CivilEngg  conscientiousness agreeableness extraversion  \
# 4             -1         -1            -0.8810       -0.2793      -1.0697
# 6             -1         -1             1.7081       -0.1054      -1.0379
# 7             -1         -1            -0.0154        1.2114       0.0100
# 10            -1         -1             0.0464        0.8128       0.0914
# 11            -1         -1            -2.2720        1.1248       0.8171
# ...          ...        ...                ...           ...          ...
# 3991         393         -1            -1.3447        0.5008      -1.6502
# 3992          -1        480             0.3555       -0.9033       0.9623
# 3993          -1         -1            -0.1082        0.3448       0.2366
# 3994          -1         -1            -0.3027        0.8784       0.9322
# 3996          -1         -1            -0.1590        0.0459      -0.4511
#
#       nueroticism  openess_to_experience
# 4         0.09163                -0.1295
# 6        -2.00920                -1.0872
# 7         0.14590                 1.2470
# 10        0.17980                 0.0284
# 11       -0.40780                -0.4455
# ...           ...                    ...
# 3991     -0.05520                 0.0284
# 3992      0.64983                -0.4229
# 3993      0.64980                -0.9194
# 3994      0.77980                -0.0943
# 3996     -0.36120                -0.0943
#
# [2123 rows x 39 columns]

# %%
time_worked_df["DOJ"] = pd.to_datetime(time_worked_df["DOJ"])
time_worked_df["DOL"] = pd.to_datetime(time_worked_df["DOL"])
# Out:
# C:\Users\bunty\AppData\Local\Temp\ipykernel_39352\101069512.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   time_worked_df["DOJ"] = pd.to_datetime(time_worked_df["DOJ"])
# C:\Users\bunty\AppData\Local\Temp\ipykernel_39352\101069512.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   time_worked_df["DOL"] = pd.to_datetime(time_worked_df["DOL"])

# %%
time_worked_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2123 entries, 4 to 3996
# Data columns (total 39 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             2123 non-null   object
#  1   ID                     2123 non-null   int64
#  2   Salary                 2123 non-null   float64
#  3   DOJ                    2123 non-null   datetime64[ns]
#  4   DOL                    2123 non-null   datetime64[ns]
#  5   Designation            2123 non-null   object
#  6   JobCity                2123 non-null   object
#  7   Gender                 2123 non-null   object
#  8   DOB                    2123 non-null   object
#  9   10percentage           2123 non-null   float64
#  10  10board                2123 non-null   object
#  11  12graduation           2123 non-null   int64
#  12  12percentage           2123 non-null   float64
#  13  12board                2123 non-null   object
#  14  CollegeID              2123 non-null   int64
#  15  CollegeTier            2123 non-null   int64
#  16  Degree                 2123 non-null   object
#  17  Specialization         2123 non-null   object
#  18  collegeGPA             2123 non-null   float64
#  19  CollegeCityID          2123 non-null   int64
#  20  CollegeCityTier        2123 non-null   int64
#  21  CollegeState           2123 non-null   object
#  22  GraduationYear         2123 non-null   int64
#  23  English                2123 non-null   int64
#  24  Logical                2123 non-null   int64
#  25  Quant                  2123 non-null   int64
#  26  Domain                 2123 non-null   float64
#  27  ComputerProgramming    2123 non-null   int64
#  28  ElectronicsAndSemicon  2123 non-null   int64
#  29  ComputerScience        2123 non-null   int64
#  30  MechanicalEngg         2123 non-null   int64
#  31  ElectricalEngg         2123 non-null   int64
#  32  TelecomEngg            2123 non-null   int64
#  33  CivilEngg              2123 non-null   int64
#  34  conscientiousness      2123 non-null   float64
#  35  agreeableness          2123 non-null   float64
#  36  extraversion           2123 non-null   float64
#  37  nueroticism            2123 non-null   float64
#  38  openess_to_experience  2123 non-null   float64
# dtypes: datetime64[ns](2), float64(10), int64(17), object(10)
# memory usage: 663.4+ KB

# %%
time_worked_df["time_of_work"] = time_worked_df["DOL"] - time_worked_df["DOJ"]

time_worked_df
# Out:
# C:\Users\bunty\AppData\Local\Temp\ipykernel_39352\4279828758.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   time_worked_df["time_of_work"] = time_worked_df["DOL"] - time_worked_df["DOJ"]
#      Unnamed: 0      ID    Salary        DOJ        DOL  \
# 4         train  343523  200000.0 2014-03-01 2015-03-01
# 6         train  947847  300000.0 2014-08-01 2015-05-01
# 7         train  912934  400000.0 2014-07-01 2015-07-01
# 10        train   87291  600000.0 2011-04-01 2015-04-01
# 11        train  190393  450000.0 2011-08-01 2014-10-01
# ...         ...     ...       ...        ...        ...
# 3991      train  230873  630000.0 2011-07-01 2014-10-01
# 3992      train  344407  800000.0 2014-04-01 2015-04-01
# 3993      train   47916  280000.0 2011-10-01 2012-10-01
# 3994      train  752781  100000.0 2013-07-01 2013-07-01
# 3996      train  947111  200000.0 2014-07-01 2015-01-01
#
#                   Designation           JobCity Gender           DOB  \
# 4                         get           Manesar      m  2/27/91 0:00
# 6      java software engineer          Banglore      m   2/1/93 0:00
# 7         mechanical engineer         Bangalore      m  5/27/92 0:00
# 10       senior php developer         Bangalore      m  6/24/89 0:00
# 11    senior systems engineer              Pune      m  2/10/90 0:00
# ...                       ...               ...    ...           ...
# 3991          systems analyst         Bangalore      m  5/20/90 0:00
# 3992                  manager            Rajkot      m  6/22/90 0:00
# 3993        software engineer        New Delhi       m  4/15/87 0:00
# 3994         technical writer         Hyderabad      f  8/27/92 0:00
# 3996       software developer  Asifabadbanglore      f  3/20/92 0:00
#
#       10percentage  ... MechanicalEngg  ElectricalEngg  TelecomEngg CivilEngg  \
# 4            78.00  ...             -1              -1           -1        -1
# 6            86.08  ...             -1              -1           -1        -1
# 7            92.00  ...            469              -1           -1        -1
# 10           88.60  ...             -1              -1           -1        -1
# 11           81.00  ...             -1              -1           -1        -1
# ...            ...  ...            ...             ...          ...       ...
# 3991         80.00  ...             -1              -1          393        -1
# 3992         73.00  ...             -1              -1           -1       480
# 3993         52.09  ...             -1              -1           -1        -1
# 3994         90.00  ...             -1              -1           -1        -1
# 3996         78.72  ...             -1              -1           -1        -1
#
#       conscientiousness  agreeableness extraversion nueroticism  \
# 4               -0.8810        -0.2793      -1.0697     0.09163
# 6                1.7081        -0.1054      -1.0379    -2.00920
# 7               -0.0154         1.2114       0.0100     0.14590
# 10               0.0464         0.8128       0.0914     0.17980
# 11              -2.2720         1.1248       0.8171    -0.40780
# ...                 ...            ...          ...         ...
# 3991            -1.3447         0.5008      -1.6502    -0.05520
# 3992             0.3555        -0.9033       0.9623     0.64983
# 3993            -0.1082         0.3448       0.2366     0.64980
# 3994            -0.3027         0.8784       0.9322     0.77980
# 3996            -0.1590         0.0459      -0.4511    -0.36120
#
#       openess_to_experience  time_of_work
# 4                   -0.1295      365 days
# 6                   -1.0872      273 days
# 7                    1.2470      365 days
# 10                   0.0284     1461 days
# 11                  -0.4455     1157 days
# ...                     ...           ...
# 3991                 0.0284     1188 days
# 3992                -0.4229      365 days
# 3993                -0.9194      366 days
# 3994                -0.0943        0 days
# 3996                -0.0943      184 days
#
# [2123 rows x 40 columns]

# %%
avg = time_worked_df["time_of_work"].mean()

avg
# Out:
# Timedelta('460 days 11:40:40.131888840')

# %%
#Ans: avg time ---> 460 days 11:40:40.131888840

# %%
avg_salary = time_worked_df["Salary"].mean()

avg_salary
# Out:
# 274236.92887423455

# %%
#Ans: avg salary ---> 274236.92887423455

# %% [markdown]
# # Count of employees still working and find no of employees have more than 1000000 salary

# %%
present = df[df['DOL'] == "present"].value_counts()

len(present)
# Out:
# 1875

# %%
present1 = df[(df['DOL'] == "present") & (df["Salary"] > 1000000)].value_counts()

len(present1)
# Out:
# 16

# %%
#Ans: count of all = 1875 and greater than 10000000 = 16

# %% [markdown]
# # Avg salary employees who are still working

# %%
present_df = df[df['DOL'] == "present"]

present_df
# Out:
#      Unnamed: 0       ID     Salary           DOJ      DOL  \
# 0         train   203097   420000.0   6/1/12 0:00  present
# 1         train   579905   500000.0   9/1/13 0:00  present
# 2         train   810601   325000.0   6/1/14 0:00  present
# 3         train   267447  1100000.0   7/1/11 0:00  present
# 5         train  1027655   300000.0   6/1/14 0:00  present
# ...         ...      ...        ...           ...      ...
# 3987      train   439787   280000.0  11/1/12 0:00  present
# 3989      train  1204604   300000.0   9/1/14 0:00  present
# 3990      train   204287   480000.0   2/1/12 0:00  present
# 3995      train   355888   320000.0   7/1/13 0:00  present
# 3997      train   324966   400000.0   2/1/13 0:00  present
#
#                       Designation    JobCity Gender            DOB  \
# 0         senior quality engineer  Bangalore      f   2/19/90 0:00
# 1               assistant manager     Indore      m   10/4/89 0:00
# 2                systems engineer    Chennai      f    8/3/92 0:00
# 3        senior software engineer    Gurgaon      m   12/5/89 0:00
# 5                 system engineer  Hyderabad      m    7/2/92 0:00
# ...                           ...        ...    ...            ...
# 3987             network engineer  New Delhi      f   1/16/90 0:00
# 3989            software engineer  Bangalore      m  11/23/91 0:00
# 3990      senior systems engineer  Hyderabad      f    9/4/89 0:00
# 3995  associate software engineer  Bangalore      m    7/3/91 0:00
# 3997      senior systems engineer    Chennai      f   2/26/91 0:00
#
#       10percentage  ... ComputerScience  MechanicalEngg  ElectricalEngg  \
# 0            84.30  ...              -1              -1              -1
# 1            85.40  ...              -1              -1              -1
# 2            85.00  ...              -1              -1              -1
# 3            85.60  ...              -1              -1              -1
# 5            89.92  ...             407              -1              -1
# ...            ...  ...             ...             ...             ...
# 3987         86.70  ...              -1              -1              -1
# 3989         74.88  ...             346              -1              -1
# 3990         88.00  ...              -1              -1              -1
# 3995         81.86  ...              -1              -1              -1
# 3997         70.60  ...              -1              -1              -1
#
#      TelecomEngg  CivilEngg  conscientiousness agreeableness extraversion  \
# 0             -1         -1             0.9737        0.8128       0.5269
# 1             -1         -1            -0.7335        0.3789       1.2396
# 2             -1         -1             0.2718        1.7109       0.1637
# 3             -1         -1             0.0464        0.3448      -0.3440
# 5             -1         -1            -0.3027       -0.6201      -2.2954
# ...          ...        ...                ...           ...          ...
# 3987          -1         -1            -1.4992       -1.8393      -0.7794
# 3989          -1         -1             0.1282        0.0459       1.2396
# 3990         233         -1             0.6646        0.3448       0.3817
# 3995          -1         -1            -1.5765       -1.5273      -1.5051
# 3997          -1         -1            -1.1128       -0.2793      -0.6343
#
#       nueroticism  openess_to_experience
# 0         1.35490                -0.4455
# 1        -0.10760                 0.8637
# 2        -0.86820                 0.6721
# 3        -0.40780                -0.9194
# 5        -0.74150                -0.8608
# ...           ...                    ...
# 3987      1.47240                -2.3017
# 3989      1.03330                 0.6721
# 3990     -1.34780                 0.8183
# 3995     -1.31840                -0.7615
# 3997      1.32553                -0.6035
#
# [1875 rows x 39 columns]

# %%
avg_salary = present_df["Salary"].mean()

avg_salary
# Out:
# 345588.8

# %%
#What is the 10th, 12th and College percentile of highest salary employee??

# %%
high_salary = df["Salary"].max()

high_salary
# Out:
# 4000000.0

# %%
high_salary_df = df[df["Salary"] == 4000000.0]

high_salary_df
# Out:
#      Unnamed: 0     ID     Salary          DOJ           DOL  \
# 1237      train  48107  4000000.0  7/1/10 0:00   3/1/15 0:00
# 2182      train  41147  4000000.0  1/1/10 0:00  12/1/11 0:00
#
#                    Designation    JobCity Gender           DOB  10percentage  \
# 1237  senior software engineer  New Delhi      m   9/9/87 0:00         90.83
# 2182       automation engineer    gurgaon      m  9/13/87 0:00         53.00
#
#       ... ComputerScience  MechanicalEngg  ElectricalEngg TelecomEngg  \
# 1237  ...              -1              -1              -1          -1
# 2182  ...              -1              -1              -1          -1
#
#       CivilEngg  conscientiousness agreeableness extraversion  nueroticism  \
# 1237         -1            -0.7264        0.0328      -1.6502      -0.8778
# 2182         -1            -3.3539       -0.4353      -1.0697      -0.0552
#
#       openess_to_experience
# 1237                -0.1295
# 2182                -2.6572
#
# [2 rows x 39 columns]

# %%
high_salary_df[["ID","Salary","10percentage","12percentage","collegeGPA","DOJ","DOL","Designation","Specialization","English","Logical","Domain"]]
# Out:
#          ID     Salary  10percentage  12percentage  collegeGPA          DOJ  \
# 1237  48107  4000000.0         90.83         88.77        72.6  7/1/10 0:00
# 2182  41147  4000000.0         53.00         61.00        65.0  1/1/10 0:00
#
#                DOL               Designation        Specialization  English  \
# 1237   3/1/15 0:00  senior software engineer  computer engineering      675
# 2182  12/1/11 0:00       automation engineer  computer application      405
#
#       Logical    Domain
# 1237      685  0.990009
# 2182      455  0.525923

# %%
h_sal_df = high_salary_df[["ID","10percentage","12percentage","collegeGPA"]]

h_sal_df
# Out:
#          ID  10percentage  12percentage  collegeGPA
# 1237  48107         90.83         88.77        72.6
# 2182  41147         53.00         61.00        65.0

# %%
melted_df = h_sal_df.melt(id_vars='ID', var_name='Exam', value_name='Percentage')

plt.figure(figsize=(10, 6))
sns.boxplot(x='Exam', y='Percentage', data=melted_df, color='skyblue')

plt.title('Box plot of Exam Percentages')
plt.xlabel('Exam')
plt.ylabel('Percentage')
plt.show()

# %%
#Compare men average salary and women salary
male_df = df[df["Gender"] == "m"]

female_df = df[df["Gender"] == "f"]

# %%
male_df
# Out:
#      Unnamed: 0       ID     Salary           DOJ           DOL  \
# 1         train   579905   500000.0   9/1/13 0:00       present
# 3         train   267447  1100000.0   7/1/11 0:00       present
# 4         train   343523   200000.0   3/1/14 0:00   3/1/15 0:00
# 5         train  1027655   300000.0   6/1/14 0:00       present
# 6         train   947847   300000.0   8/1/14 0:00   5/1/15 0:00
# ...         ...      ...        ...           ...           ...
# 3989      train  1204604   300000.0   9/1/14 0:00       present
# 3991      train   230873   630000.0   7/1/11 0:00  10/1/14 0:00
# 3992      train   344407   800000.0   4/1/14 0:00   4/1/15 0:00
# 3993      train    47916   280000.0  10/1/11 0:00  10/1/12 0:00
# 3995      train   355888   320000.0   7/1/13 0:00       present
#
#                       Designation     JobCity Gender            DOB  \
# 1               assistant manager      Indore      m   10/4/89 0:00
# 3        senior software engineer     Gurgaon      m   12/5/89 0:00
# 4                             get     Manesar      m   2/27/91 0:00
# 5                 system engineer   Hyderabad      m    7/2/92 0:00
# 6          java software engineer    Banglore      m    2/1/93 0:00
# ...                           ...         ...    ...            ...
# 3989            software engineer   Bangalore      m  11/23/91 0:00
# 3991              systems analyst   Bangalore      m   5/20/90 0:00
# 3992                      manager      Rajkot      m   6/22/90 0:00
# 3993            software engineer  New Delhi       m   4/15/87 0:00
# 3995  associate software engineer   Bangalore      m    7/3/91 0:00
#
#       10percentage  ... ComputerScience  MechanicalEngg  ElectricalEngg  \
# 1            85.40  ...              -1              -1              -1
# 3            85.60  ...              -1              -1              -1
# 4            78.00  ...              -1              -1              -1
# 5            89.92  ...             407              -1              -1
# 6            86.08  ...             346              -1              -1
# ...            ...  ...             ...             ...             ...
# 3989         74.88  ...             346              -1              -1
# 3991         80.00  ...              -1              -1              -1
# 3992         73.00  ...              -1              -1              -1
# 3993         52.09  ...              -1              -1              -1
# 3995         81.86  ...              -1              -1              -1
#
#      TelecomEngg  CivilEngg  conscientiousness agreeableness extraversion  \
# 1             -1         -1            -0.7335        0.3789       1.2396
# 3             -1         -1             0.0464        0.3448      -0.3440
# 4             -1         -1            -0.8810       -0.2793      -1.0697
# 5             -1         -1            -0.3027       -0.6201      -2.2954
# 6             -1         -1             1.7081       -0.1054      -1.0379
# ...          ...        ...                ...           ...          ...
# 3989          -1         -1             0.1282        0.0459       1.2396
# 3991         393         -1            -1.3447        0.5008      -1.6502
# 3992          -1        480             0.3555       -0.9033       0.9623
# 3993          -1         -1            -0.1082        0.3448       0.2366
# 3995          -1         -1            -1.5765       -1.5273      -1.5051
#
#       nueroticism  openess_to_experience
# 1        -0.10760                 0.8637
# 3        -0.40780                -0.9194
# 4         0.09163                -0.1295
# 5        -0.74150                -0.8608
# 6        -2.00920                -1.0872
# ...           ...                    ...
# 3989      1.03330                 0.6721
# 3991     -0.05520                 0.0284
# 3992      0.64983                -0.4229
# 3993      0.64980                -0.9194
# 3995     -1.31840                -0.7615
#
# [3041 rows x 39 columns]

# %%
male_df["Salary"].mean()
# Out:
# 311716.21177244326

# %%
female_df
# Out:
#      Unnamed: 0      ID    Salary           DOJ          DOL  \
# 0         train  203097  420000.0   6/1/12 0:00      present
# 2         train  810601  325000.0   6/1/14 0:00      present
# 15        train  536517  350000.0   8/1/13 0:00      present
# 19        train  466888  325000.0   9/1/14 0:00      present
# 20        train  140069  320000.0  11/1/10 0:00  9/1/12 0:00
# ...         ...     ...       ...           ...          ...
# 3988      train  466661  200000.0   2/1/13 0:00  7/1/13 0:00
# 3990      train  204287  480000.0   2/1/12 0:00      present
# 3994      train  752781  100000.0   7/1/13 0:00  7/1/13 0:00
# 3996      train  947111  200000.0   7/1/14 0:00  1/1/15 0:00
# 3997      train  324966  400000.0   2/1/13 0:00      present
#
#                   Designation           JobCity Gender            DOB  \
# 0     senior quality engineer         Bangalore      f   2/19/90 0:00
# 2            systems engineer           Chennai      f    8/3/92 0:00
# 15           network engineer                -1      f   1/17/90 0:00
# 19          software engineer              Pune      f  11/30/90 0:00
# 20          software engineer         Bangalore      f   7/25/88 0:00
# ...                       ...               ...    ...            ...
# 3988             data analyst         Bangalore      f   5/15/91 0:00
# 3990  senior systems engineer         Hyderabad      f    9/4/89 0:00
# 3994         technical writer         Hyderabad      f   8/27/92 0:00
# 3996       software developer  Asifabadbanglore      f   3/20/92 0:00
# 3997  senior systems engineer           Chennai      f   2/26/91 0:00
#
#       10percentage  ... ComputerScience  MechanicalEngg  ElectricalEngg  \
# 0            84.30  ...              -1              -1              -1
# 2            85.00  ...              -1              -1              -1
# 15           69.54  ...              -1              -1              -1
# 19           79.00  ...              -1              -1              -1
# 20           91.20  ...              -1              -1              -1
# ...            ...  ...             ...             ...             ...
# 3988         74.40  ...              -1              -1              -1
# 3990         88.00  ...              -1              -1              -1
# 3994         90.00  ...              -1              -1              -1
# 3996         78.72  ...             438              -1              -1
# 3997         70.60  ...              -1              -1              -1
#
#      TelecomEngg  CivilEngg  conscientiousness agreeableness extraversion  \
# 0             -1         -1             0.9737        0.8128       0.5269
# 2             -1         -1             0.2718        1.7109       0.1637
# 15            -1         -1             1.7465        1.9048       0.6720
# 19            -1         -1             0.8192        0.2668      -0.2714
# 20            -1         -1            -0.1082        0.9688       0.5269
# ...          ...        ...                ...           ...          ...
# 3988          -1         -1            -0.5332       -0.1232      -0.0537
# 3990         233         -1             0.6646        0.3448       0.3817
# 3994          -1         -1            -0.3027        0.8784       0.9322
# 3996          -1         -1            -0.1590        0.0459      -0.4511
# 3997          -1         -1            -1.1128       -0.2793      -0.6343
#
#       nueroticism  openess_to_experience
# 0         1.35490                -0.4455
# 2        -0.86820                 0.6721
# 15       -0.29020                 1.2528
# 19       -0.40780                -0.1295
# 20       -0.29020                 0.3444
# ...           ...                    ...
# 3988      1.32550                 0.5024
# 3990     -1.34780                 0.8183
# 3994      0.77980                -0.0943
# 3996     -0.36120                -0.0943
# 3997      1.32553                -0.6035
#
# [957 rows x 39 columns]

# %%
female_df["Salary"].mean()
# Out:
# 294937.3040752351

# %%
#Ans: avg salary male = 311716.21177244326, female = 294937.3040752351

# %% [markdown]
# Find the count of men and women who left the company and not left the company and for every thing find salary greater than 500000

# %%
time_worked_df
# Out:
#      Unnamed: 0      ID    Salary        DOJ        DOL  \
# 4         train  343523  200000.0 2014-03-01 2015-03-01
# 6         train  947847  300000.0 2014-08-01 2015-05-01
# 7         train  912934  400000.0 2014-07-01 2015-07-01
# 10        train   87291  600000.0 2011-04-01 2015-04-01
# 11        train  190393  450000.0 2011-08-01 2014-10-01
# ...         ...     ...       ...        ...        ...
# 3991      train  230873  630000.0 2011-07-01 2014-10-01
# 3992      train  344407  800000.0 2014-04-01 2015-04-01
# 3993      train   47916  280000.0 2011-10-01 2012-10-01
# 3994      train  752781  100000.0 2013-07-01 2013-07-01
# 3996      train  947111  200000.0 2014-07-01 2015-01-01
#
#                   Designation           JobCity Gender           DOB  \
# 4                         get           Manesar      m  2/27/91 0:00
# 6      java software engineer          Banglore      m   2/1/93 0:00
# 7         mechanical engineer         Bangalore      m  5/27/92 0:00
# 10       senior php developer         Bangalore      m  6/24/89 0:00
# 11    senior systems engineer              Pune      m  2/10/90 0:00
# ...                       ...               ...    ...           ...
# 3991          systems analyst         Bangalore      m  5/20/90 0:00
# 3992                  manager            Rajkot      m  6/22/90 0:00
# 3993        software engineer        New Delhi       m  4/15/87 0:00
# 3994         technical writer         Hyderabad      f  8/27/92 0:00
# 3996       software developer  Asifabadbanglore      f  3/20/92 0:00
#
#       10percentage  ... MechanicalEngg  ElectricalEngg  TelecomEngg CivilEngg  \
# 4            78.00  ...             -1              -1           -1        -1
# 6            86.08  ...             -1              -1           -1        -1
# 7            92.00  ...            469              -1           -1        -1
# 10           88.60  ...             -1              -1           -1        -1
# 11           81.00  ...             -1              -1           -1        -1
# ...            ...  ...            ...             ...          ...       ...
# 3991         80.00  ...             -1              -1          393        -1
# 3992         73.00  ...             -1              -1           -1       480
# 3993         52.09  ...             -1              -1           -1        -1
# 3994         90.00  ...             -1              -1           -1        -1
# 3996         78.72  ...             -1              -1           -1        -1
#
#       conscientiousness  agreeableness extraversion nueroticism  \
# 4               -0.8810        -0.2793      -1.0697     0.09163
# 6                1.7081        -0.1054      -1.0379    -2.00920
# 7               -0.0154         1.2114       0.0100     0.14590
# 10               0.0464         0.8128       0.0914     0.17980
# 11              -2.2720         1.1248       0.8171    -0.40780
# ...                 ...            ...          ...         ...
# 3991            -1.3447         0.5008      -1.6502    -0.05520
# 3992             0.3555        -0.9033       0.9623     0.64983
# 3993            -0.1082         0.3448       0.2366     0.64980
# 3994            -0.3027         0.8784       0.9322     0.77980
# 3996            -0.1590         0.0459      -0.4511    -0.36120
#
#       openess_to_experience  time_of_work
# 4                   -0.1295      365 days
# 6                   -1.0872      273 days
# 7                    1.2470      365 days
# 10                   0.0284     1461 days
# 11                  -0.4455     1157 days
# ...                     ...           ...
# 3991                 0.0284     1188 days
# 3992                -0.4229      365 days
# 3993                -0.9194      366 days
# 3994                -0.0943        0 days
# 3996                -0.0943      184 days
#
# [2123 rows x 40 columns]

# %%
len(time_worked_df[time_worked_df["Gender"] == "f"].value_counts())
# Out:
# 509

# %%
len(time_worked_df[(time_worked_df["Gender"] == "f") & (time_worked_df["Salary"] > 500000)].value_counts())
# Out:
# 22

# %%
len(time_worked_df[time_worked_df["Gender"] == "m"].value_counts())
# Out:
# 1614

# %%
len(time_worked_df[(time_worked_df["Gender"] == "m") & (time_worked_df["Salary"] > 500000)].value_counts())
# Out:
# 91

# %%
len(present_df[present_df["Gender"] == "f"].value_counts())
# Out:
# 448

# %%
len(present_df[(present_df["Gender"] == "f") & (present_df["Salary"] > 500000)].value_counts())
# Out:
# 28

# %%
len(present_df[present_df["Gender"] == "m"].value_counts())
# Out:
# 1427

# %%
len(present_df[(present_df["Gender"] == "m") & (present_df["Salary"] > 500000)].value_counts())
# Out:
# 174

# %% [markdown]
# #Ans: left women: 509,22 , men: 1614,91 ; present women: 448,28 , men: 1427,174

# %% [markdown]
# # Filter the df with job city and find the avg Salary

# %%
filtered_df = df[df["JobCity"] != -1]

filtered_df
# Out:
#      Unnamed: 0      ID     Salary           DOJ           DOL  \
# 0         train  203097   420000.0   6/1/12 0:00       present
# 1         train  579905   500000.0   9/1/13 0:00       present
# 2         train  810601   325000.0   6/1/14 0:00       present
# 3         train  267447  1100000.0   7/1/11 0:00       present
# 4         train  343523   200000.0   3/1/14 0:00   3/1/15 0:00
# ...         ...     ...        ...           ...           ...
# 3993      train   47916   280000.0  10/1/11 0:00  10/1/12 0:00
# 3994      train  752781   100000.0   7/1/13 0:00   7/1/13 0:00
# 3995      train  355888   320000.0   7/1/13 0:00       present
# 3996      train  947111   200000.0   7/1/14 0:00   1/1/15 0:00
# 3997      train  324966   400000.0   2/1/13 0:00       present
#
#                       Designation           JobCity Gender           DOB  \
# 0         senior quality engineer         Bangalore      f  2/19/90 0:00
# 1               assistant manager            Indore      m  10/4/89 0:00
# 2                systems engineer           Chennai      f   8/3/92 0:00
# 3        senior software engineer           Gurgaon      m  12/5/89 0:00
# 4                             get           Manesar      m  2/27/91 0:00
# ...                           ...               ...    ...           ...
# 3993            software engineer        New Delhi       m  4/15/87 0:00
# 3994             technical writer         Hyderabad      f  8/27/92 0:00
# 3995  associate software engineer         Bangalore      m   7/3/91 0:00
# 3996           software developer  Asifabadbanglore      f  3/20/92 0:00
# 3997      senior systems engineer           Chennai      f  2/26/91 0:00
#
#       10percentage  ... ComputerScience  MechanicalEngg  ElectricalEngg  \
# 0            84.30  ...              -1              -1              -1
# 1            85.40  ...              -1              -1              -1
# 2            85.00  ...              -1              -1              -1
# 3            85.60  ...              -1              -1              -1
# 4            78.00  ...              -1              -1              -1
# ...            ...  ...             ...             ...             ...
# 3993         52.09  ...              -1              -1              -1
# 3994         90.00  ...              -1              -1              -1
# 3995         81.86  ...              -1              -1              -1
# 3996         78.72  ...             438              -1              -1
# 3997         70.60  ...              -1              -1              -1
#
#      TelecomEngg  CivilEngg  conscientiousness agreeableness extraversion  \
# 0             -1         -1             0.9737        0.8128       0.5269
# 1             -1         -1            -0.7335        0.3789       1.2396
# 2             -1         -1             0.2718        1.7109       0.1637
# 3             -1         -1             0.0464        0.3448      -0.3440
# 4             -1         -1            -0.8810       -0.2793      -1.0697
# ...          ...        ...                ...           ...          ...
# 3993          -1         -1            -0.1082        0.3448       0.2366
# 3994          -1         -1            -0.3027        0.8784       0.9322
# 3995          -1         -1            -1.5765       -1.5273      -1.5051
# 3996          -1         -1            -0.1590        0.0459      -0.4511
# 3997          -1         -1            -1.1128       -0.2793      -0.6343
#
#       nueroticism  openess_to_experience
# 0         1.35490                -0.4455
# 1        -0.10760                 0.8637
# 2        -0.86820                 0.6721
# 3        -0.40780                -0.9194
# 4         0.09163                -0.1295
# ...           ...                    ...
# 3993      0.64980                -0.9194
# 3994      0.77980                -0.0943
# 3995     -1.31840                -0.7615
# 3996     -0.36120                -0.0943
# 3997      1.32553                -0.6035
#
# [3998 rows x 39 columns]

# %%
filtered_df["Salary"].mean()
# Out:
# 307699.8499249625

# %% [markdown]
# # In which year most of the employees left the company and what is the lowesr salary in that year

# %%
time_worked_df['time_column'] = pd.to_datetime(time_worked_df['DOL'], format='%m/%d/%Y %I:%M:%S %p')

time_worked_df
# Out:
# C:\Users\bunty\AppData\Local\Temp\ipykernel_39352\2577270195.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   time_worked_df['time_column'] = pd.to_datetime(time_worked_df['DOL'], format='%m/%d/%Y %I:%M:%S %p')
#      Unnamed: 0      ID    Salary        DOJ        DOL  \
# 4         train  343523  200000.0 2014-03-01 2015-03-01
# 6         train  947847  300000.0 2014-08-01 2015-05-01
# 7         train  912934  400000.0 2014-07-01 2015-07-01
# 10        train   87291  600000.0 2011-04-01 2015-04-01
# 11        train  190393  450000.0 2011-08-01 2014-10-01
# ...         ...     ...       ...        ...        ...
# 3991      train  230873  630000.0 2011-07-01 2014-10-01
# 3992      train  344407  800000.0 2014-04-01 2015-04-01
# 3993      train   47916  280000.0 2011-10-01 2012-10-01
# 3994      train  752781  100000.0 2013-07-01 2013-07-01
# 3996      train  947111  200000.0 2014-07-01 2015-01-01
#
#                   Designation           JobCity Gender           DOB  \
# 4                         get           Manesar      m  2/27/91 0:00
# 6      java software engineer          Banglore      m   2/1/93 0:00
# 7         mechanical engineer         Bangalore      m  5/27/92 0:00
# 10       senior php developer         Bangalore      m  6/24/89 0:00
# 11    senior systems engineer              Pune      m  2/10/90 0:00
# ...                       ...               ...    ...           ...
# 3991          systems analyst         Bangalore      m  5/20/90 0:00
# 3992                  manager            Rajkot      m  6/22/90 0:00
# 3993        software engineer        New Delhi       m  4/15/87 0:00
# 3994         technical writer         Hyderabad      f  8/27/92 0:00
# 3996       software developer  Asifabadbanglore      f  3/20/92 0:00
#
#       10percentage  ... ElectricalEngg  TelecomEngg  CivilEngg  \
# 4            78.00  ...             -1           -1         -1
# 6            86.08  ...             -1           -1         -1
# 7            92.00  ...             -1           -1         -1
# 10           88.60  ...             -1           -1         -1
# 11           81.00  ...             -1           -1         -1
# ...            ...  ...            ...          ...        ...
# 3991         80.00  ...             -1          393         -1
# 3992         73.00  ...             -1           -1        480
# 3993         52.09  ...             -1           -1         -1
# 3994         90.00  ...             -1           -1         -1
# 3996         78.72  ...             -1           -1         -1
#
#      conscientiousness  agreeableness  extraversion nueroticism  \
# 4              -0.8810        -0.2793       -1.0697     0.09163
# 6               1.7081        -0.1054       -1.0379    -2.00920
# 7              -0.0154         1.2114        0.0100     0.14590
# 10              0.0464         0.8128        0.0914     0.17980
# 11             -2.2720         1.1248        0.8171    -0.40780
# ...                ...            ...           ...         ...
# 3991           -1.3447         0.5008       -1.6502    -0.05520
# 3992            0.3555        -0.9033        0.9623     0.64983
# 3993           -0.1082         0.3448        0.2366     0.64980
# 3994           -0.3027         0.8784        0.9322     0.77980
# 3996           -0.1590         0.0459       -0.4511    -0.36120
#
#      openess_to_experience  time_of_work  time_column
# 4                  -0.1295      365 days   2015-03-01
# 6                  -1.0872      273 days   2015-05-01
# 7                   1.2470      365 days   2015-07-01
# 10                  0.0284     1461 days   2015-04-01
# 11                 -0.4455     1157 days   2014-10-01
# ...                    ...           ...          ...
# 3991                0.0284     1188 days   2014-10-01
# 3992               -0.4229      365 days   2015-04-01
# 3993               -0.9194      366 days   2012-10-01
# 3994               -0.0943        0 days   2013-07-01
# 3996               -0.0943      184 days   2015-01-01
#
# [2123 rows x 41 columns]

# %%
time_worked_df['year'] = time_worked_df['time_column'].dt.year

time_worked_df
# Out:
# C:\Users\bunty\AppData\Local\Temp\ipykernel_39352\949596930.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   time_worked_df['year'] = time_worked_df['time_column'].dt.year
#      Unnamed: 0      ID    Salary        DOJ        DOL  \
# 4         train  343523  200000.0 2014-03-01 2015-03-01
# 6         train  947847  300000.0 2014-08-01 2015-05-01
# 7         train  912934  400000.0 2014-07-01 2015-07-01
# 10        train   87291  600000.0 2011-04-01 2015-04-01
# 11        train  190393  450000.0 2011-08-01 2014-10-01
# ...         ...     ...       ...        ...        ...
# 3991      train  230873  630000.0 2011-07-01 2014-10-01
# 3992      train  344407  800000.0 2014-04-01 2015-04-01
# 3993      train   47916  280000.0 2011-10-01 2012-10-01
# 3994      train  752781  100000.0 2013-07-01 2013-07-01
# 3996      train  947111  200000.0 2014-07-01 2015-01-01
#
#                   Designation           JobCity Gender           DOB  \
# 4                         get           Manesar      m  2/27/91 0:00
# 6      java software engineer          Banglore      m   2/1/93 0:00
# 7         mechanical engineer         Bangalore      m  5/27/92 0:00
# 10       senior php developer         Bangalore      m  6/24/89 0:00
# 11    senior systems engineer              Pune      m  2/10/90 0:00
# ...                       ...               ...    ...           ...
# 3991          systems analyst         Bangalore      m  5/20/90 0:00
# 3992                  manager            Rajkot      m  6/22/90 0:00
# 3993        software engineer        New Delhi       m  4/15/87 0:00
# 3994         technical writer         Hyderabad      f  8/27/92 0:00
# 3996       software developer  Asifabadbanglore      f  3/20/92 0:00
#
#       10percentage  ... TelecomEngg  CivilEngg  conscientiousness  \
# 4            78.00  ...          -1         -1            -0.8810
# 6            86.08  ...          -1         -1             1.7081
# 7            92.00  ...          -1         -1            -0.0154
# 10           88.60  ...          -1         -1             0.0464
# 11           81.00  ...          -1         -1            -2.2720
# ...            ...  ...         ...        ...                ...
# 3991         80.00  ...         393         -1            -1.3447
# 3992         73.00  ...          -1        480             0.3555
# 3993         52.09  ...          -1         -1            -0.1082
# 3994         90.00  ...          -1         -1            -0.3027
# 3996         78.72  ...          -1         -1            -0.1590
#
#      agreeableness  extraversion  nueroticism openess_to_experience  \
# 4          -0.2793       -1.0697      0.09163               -0.1295
# 6          -0.1054       -1.0379     -2.00920               -1.0872
# 7           1.2114        0.0100      0.14590                1.2470
# 10          0.8128        0.0914      0.17980                0.0284
# 11          1.1248        0.8171     -0.40780               -0.4455
# ...            ...           ...          ...                   ...
# 3991        0.5008       -1.6502     -0.05520                0.0284
# 3992       -0.9033        0.9623      0.64983               -0.4229
# 3993        0.3448        0.2366      0.64980               -0.9194
# 3994        0.8784        0.9322      0.77980               -0.0943
# 3996        0.0459       -0.4511     -0.36120               -0.0943
#
#      time_of_work  time_column  year
# 4        365 days   2015-03-01  2015
# 6        273 days   2015-05-01  2015
# 7        365 days   2015-07-01  2015
# 10      1461 days   2015-04-01  2015
# 11      1157 days   2014-10-01  2014
# ...           ...          ...   ...
# 3991    1188 days   2014-10-01  2014
# 3992     365 days   2015-04-01  2015
# 3993     366 days   2012-10-01  2012
# 3994       0 days   2013-07-01  2013
# 3996     184 days   2015-01-01  2015
#
# [2123 rows x 42 columns]

# %%
time_worked_df["year"].unique()
# Out:
# array([2015, 2014, 2012, 2013, 2011, 2005, 2010, 2009, 2008], dtype=int64)

# %%
year_counts = time_worked_df['year'].value_counts()

year_counts
# Out:
# 2015    1059
# 2014     646
# 2013     255
# 2012     116
# 2011      40
# 2010       4
# 2005       1
# 2009       1
# 2008       1
# Name: year, dtype: int64

# %%
year_counts.max()
# Out:
# 1059

# %%
year = year_counts[year_counts == year_counts.max()].index

year
# Out:
# Int64Index([2015], dtype='int64')

# %%
_2015_left_df = time_worked_df[(time_worked_df["year"] == 2015)]

_2015_left_df["Salary"].min()
# Out:
# 35000.0

# %%
#Ans: 2015 and 35000.0

# %% [markdown]
# # graph for the above question

# %%
year_counts_sorted = year_counts.sort_index()

# %%
plt.figure(figsize=(15, 7))
plt.bar(year_counts_sorted.index, year_counts_sorted.values, color='skyblue')
plt.xlabel('Year')
plt.ylabel('Count')
plt.title('Count of Years')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
x = year_counts_sorted.index
y = year_counts_sorted.values

coefficients = np.polyfit(x, y,2)
poly = np.poly1d(coefficients)
x_fit = np.linspace(min(x), max(x),100)
y_fit = poly(x_fit)

plt.figure(figsize=(10, 5))
plt.bar(x, y, color='orange')

plt.plot(x_fit, y_fit, color='grey', linestyle='-', linewidth=2)

plt.xlabel('Year')
plt.ylabel('Count')
plt.title('Count of Years with Parabolic Fit')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Gender', y='Salary', data=df, hue='Gender', palette='Set2')
plt.xlabel('Gender')
plt.ylabel('Salary')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.title('Box Plot of Openness to Experience by Gender')
plt.yscale('linear')
plt.tight_layout()
plt.show()

# %%
#removing outliers

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Gender', y='Salary', data=df, hue='Gender', palette='Set2', showfliers=False)
plt.xlabel('Gender')
plt.ylabel('Salary')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.title('Box Plot of Openness to Experience by Gender (without outliers)')
plt.yscale('linear')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Consider qualities of employee and find avg. Compare between female and male

# %%
df["avg_quality"] = (df["conscientiousness"] + df["agreeableness"] + df["extraversion"] + df["nueroticism"] + df["openess_to_experience"])/5

df
# Out:
#      Unnamed: 0      ID     Salary           DOJ           DOL  \
# 0         train  203097   420000.0   6/1/12 0:00       present
# 1         train  579905   500000.0   9/1/13 0:00       present
# 2         train  810601   325000.0   6/1/14 0:00       present
# 3         train  267447  1100000.0   7/1/11 0:00       present
# 4         train  343523   200000.0   3/1/14 0:00   3/1/15 0:00
# ...         ...     ...        ...           ...           ...
# 3993      train   47916   280000.0  10/1/11 0:00  10/1/12 0:00
# 3994      train  752781   100000.0   7/1/13 0:00   7/1/13 0:00
# 3995      train  355888   320000.0   7/1/13 0:00       present
# 3996      train  947111   200000.0   7/1/14 0:00   1/1/15 0:00
# 3997      train  324966   400000.0   2/1/13 0:00       present
#
#                       Designation           JobCity Gender           DOB  \
# 0         senior quality engineer         Bangalore      f  2/19/90 0:00
# 1               assistant manager            Indore      m  10/4/89 0:00
# 2                systems engineer           Chennai      f   8/3/92 0:00
# 3        senior software engineer           Gurgaon      m  12/5/89 0:00
# 4                             get           Manesar      m  2/27/91 0:00
# ...                           ...               ...    ...           ...
# 3993            software engineer        New Delhi       m  4/15/87 0:00
# 3994             technical writer         Hyderabad      f  8/27/92 0:00
# 3995  associate software engineer         Bangalore      m   7/3/91 0:00
# 3996           software developer  Asifabadbanglore      f  3/20/92 0:00
# 3997      senior systems engineer           Chennai      f  2/26/91 0:00
#
#       10percentage  ... MechanicalEngg  ElectricalEngg  TelecomEngg CivilEngg  \
# 0            84.30  ...             -1              -1           -1        -1
# 1            85.40  ...             -1              -1           -1        -1
# 2            85.00  ...             -1              -1           -1        -1
# 3            85.60  ...             -1              -1           -1        -1
# 4            78.00  ...             -1              -1           -1        -1
# ...            ...  ...            ...             ...          ...       ...
# 3993         52.09  ...             -1              -1           -1        -1
# 3994         90.00  ...             -1              -1           -1        -1
# 3995         81.86  ...             -1              -1           -1        -1
# 3996         78.72  ...             -1              -1           -1        -1
# 3997         70.60  ...             -1              -1           -1        -1
#
#       conscientiousness  agreeableness extraversion nueroticism  \
# 0                0.9737         0.8128       0.5269     1.35490
# 1               -0.7335         0.3789       1.2396    -0.10760
# 2                0.2718         1.7109       0.1637    -0.86820
# 3                0.0464         0.3448      -0.3440    -0.40780
# 4               -0.8810        -0.2793      -1.0697     0.09163
# ...                 ...            ...          ...         ...
# 3993            -0.1082         0.3448       0.2366     0.64980
# 3994            -0.3027         0.8784       0.9322     0.77980
# 3995            -1.5765        -1.5273      -1.5051    -1.31840
# 3996            -0.1590         0.0459      -0.4511    -0.36120
# 3997            -1.1128        -0.2793      -0.6343     1.32553
#
#       openess_to_experience  avg_quality
# 0                   -0.4455     0.644560
# 1                    0.8637     0.328220
# 2                    0.6721     0.390060
# 3                   -0.9194    -0.256000
# 4                   -0.1295    -0.453574
# ...                     ...          ...
# 3993                -0.9194     0.040720
# 3994                -0.0943     0.438680
# 3995                -0.7615    -1.337760
# 3996                -0.0943    -0.203940
# 3997                -0.6035    -0.260874
#
# [3998 rows x 40 columns]

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Gender', y='avg_quality', data=df, hue='Gender', palette='Set2', )
plt.xlabel('Gender')
plt.ylabel('Quality')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.title('Box Plot of Quality by Gender (without outliers)')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Gender', y='avg_quality', data=df, hue='Gender', palette='Set2', showfliers=False)
plt.xlabel('Gender')
plt.ylabel('Quality')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.title('Box Plot of avg_quality by Gender')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Plot the Salary quality graph

# %%
df["avg_quality"]
# Out:
# 0       0.644560
# 1       0.328220
# 2       0.390060
# 3      -0.256000
# 4      -0.453574
#           ...
# 3993    0.040720
# 3994    0.438680
# 3995   -1.337760
# 3996   -0.203940
# 3997   -0.260874
# Name: avg_quality, Length: 3998, dtype: float64

# %%
sns.scatterplot(data=df, x='Salary', y='avg_quality')

plt.xlabel('Salary')
plt.ylabel('Avg Quality')
plt.title('Salary vs Avg Quality')

plt.show()

# %% [markdown]
# # Research Quetions
# Times of India article dated Jan 18, 2019 states that “After doing your Computer Science Engineering if you take up jobs as a Programming Analyst, Software Engineer, Hardware Engineer and Associate Engineer you can earn up to 2.5-3 lakhs as a fresh graduate.” Test this claim with the data given to you.

# %%
df_18_1_19 = df[(df["DOJ"] < "18/1/19 0:00") & (df["Specialization"] == "computer science & engineering") & (df["Designation"].isin(["programming analyst", "software engineer", "hardware engineer", "associate engineer"]))]

df_18_1_19
# Out:
#      Unnamed: 0       ID     Salary           DOJ           DOL  \
# 113       train  1087220   340000.0   1/1/15 0:00       present
# 115       train   815219   330000.0  12/1/13 0:00   4/1/15 0:00
# 205       train  1171130   325000.0   1/1/15 0:00       present
# 290       train  1009094   560000.0  11/1/14 0:00       present
# 328       train  1203085   785000.0  10/1/14 0:00       present
# 432       train   896469   475000.0  12/1/14 0:00   5/1/15 0:00
# 499       train   845544   300000.0  11/1/14 0:00   5/1/15 0:00
# 603       train   820700   265000.0   1/1/15 0:00       present
# 704       train   552730   375000.0   1/1/14 0:00       present
# 723       train   958388   420000.0  11/1/13 0:00       present
# 724       train   431853   215000.0   1/1/13 0:00  11/1/14 0:00
# 765       train   493696   350000.0  10/1/13 0:00   4/1/15 0:00
# 933       train  1259836   330000.0  12/1/14 0:00       present
# 976       train   806424   350000.0  12/1/14 0:00       present
# 1059      train  1224952   325000.0  11/1/14 0:00   3/1/15 0:00
# 1300      train  1198934   275000.0  12/1/14 0:00       present
# 1494      train  1124919   315000.0  10/1/14 0:00       present
# 1618      train   896516   310000.0   1/1/14 0:00       present
# 1653      train   553327   300000.0  12/1/13 0:00       present
# 1743      train  1218931   200000.0  10/1/14 0:00       present
# 1896      train   613031   350000.0   1/1/14 0:00   4/1/15 0:00
# 1926      train   553781   310000.0  12/1/13 0:00       present
# 1949      train   991139   320000.0  10/1/14 0:00       present
# 2040      train   552751   590000.0  11/1/13 0:00   1/1/15 0:00
# 2118      train   640930   310000.0  12/1/13 0:00   4/1/15 0:00
# 2298      train   425527   180000.0   1/1/13 0:00   9/1/13 0:00
# 2391      train   729448   350000.0  12/1/13 0:00       present
# 2472      train  1283372  1000000.0   1/1/15 0:00       present
# 2577      train   909180   350000.0  12/1/13 0:00       present
# 2722      train   656053   305000.0  12/1/13 0:00       present
# 2728      train  1063653   110000.0   1/1/14 0:00   4/1/14 0:00
# 2739      train  1149622   220000.0   1/1/14 0:00       present
# 2878      train   670628   340000.0  12/1/13 0:00   4/1/15 0:00
# 2898      train   325868   210000.0   1/1/13 0:00   2/1/14 0:00
# 3286      train   910160   195000.0   1/1/14 0:00       present
# 3357      train  1239552   300000.0  12/1/14 0:00       present
# 3396      train   737310   480000.0  12/1/13 0:00       present
# 3511      train   670536   360000.0  10/1/13 0:00       present
# 3653      train   801301   200000.0  12/1/13 0:00  12/1/14 0:00
# 3746      train  1100909   325000.0  11/1/14 0:00       present
# 3778      train  1083136   300000.0  10/1/14 0:00   4/1/15 0:00
# 3795      train   553645   350000.0  11/1/13 0:00       present
# 3829      train   628220   315000.0   1/1/14 0:00       present
# 3881      train   982135   600000.0   1/1/14 0:00       present
# 3917      train   638674   105000.0  10/1/14 0:00   4/1/15 0:00
# 3959      train   775902   390000.0   1/1/14 0:00   4/1/15 0:00
#
#             Designation             JobCity Gender            DOB  \
# 113   software engineer           Hyderabad      m   4/18/91 0:00
# 115   software engineer             Chennai      m   1/13/92 0:00
# 205   software engineer               Noida      m   3/21/92 0:00
# 290   software engineer           Bangalore      m  12/17/91 0:00
# 328   software engineer           Bangalore      m  10/20/91 0:00
# 432   software engineer           Bangalore      m   5/29/92 0:00
# 499   software engineer  Thiruvananthapuram      f   12/4/92 0:00
# 603   software engineer               Noida      m    2/5/92 0:00
# 704   software engineer           Hyderabad      f    3/7/92 0:00
# 723   software engineer                Pune      m   10/2/91 0:00
# 724   software engineer               Noida      m    4/4/91 0:00
# 765   software engineer            Chennai       m   7/21/90 0:00
# 933   software engineer             Chennai      m   2/26/92 0:00
# 976   software engineer             Gurgaon      m    9/7/92 0:00
# 1059  software engineer           Bangalore      m   7/15/91 0:00
# 1300  software engineer           Hyderabad      m  10/31/92 0:00
# 1494  software engineer         Navi Mumbai      f    5/8/92 0:00
# 1618  software engineer           Bangalore      m  12/25/91 0:00
# 1653  software engineer                  -1      m    7/3/92 0:00
# 1743  software engineer               Noida      m    1/9/94 0:00
# 1896  software engineer         Navi Mumbai      m   7/21/92 0:00
# 1926  software engineer             Gurgaon      m   6/23/88 0:00
# 1949  software engineer           bangalore      m  10/23/92 0:00
# 2040  software engineer                  -1      m    3/2/91 0:00
# 2118  software engineer                  -1      m   2/27/91 0:00
# 2298  software engineer               Noida      m   4/14/89 0:00
# 2391  software engineer           Bangalore      f   1/29/91 0:00
# 2472  software engineer               Noida      m  11/21/91 0:00
# 2577  software engineer           Bangalore      m    3/7/90 0:00
# 2722  software engineer           bangalore      f   9/19/90 0:00
# 2728  software engineer             Gurgaon      m  11/14/91 0:00
# 2739  software engineer           Hyderabad      m   11/1/90 0:00
# 2878  software engineer              Mumbai      m   10/8/91 0:00
# 2898  software engineer           Hyderabad      f   8/24/91 0:00
# 3286  software engineer        Kochi/Cochin      m   5/21/93 0:00
# 3357  software engineer           Bangalore      m   7/20/90 0:00
# 3396  software engineer               Noida      f    5/9/90 0:00
# 3511  software engineer               Noida      m   1/11/91 0:00
# 3653  software engineer              mohali      m    9/5/91 0:00
# 3746  software engineer          Bangalore       m    8/9/92 0:00
# 3778  software engineer         Navi Mumbai      m  11/24/90 0:00
# 3795  software engineer               Noida      m   11/8/90 0:00
# 3829  software engineer             Gurgaon      m   1/14/91 0:00
# 3881  software engineer           Bangalore      m   1/31/92 0:00
# 3917  software engineer        Kochi/Cochin      f  12/14/91 0:00
# 3959  software engineer             Gurgaon      m   9/30/91 0:00
#
#       10percentage  ... MechanicalEngg  ElectricalEngg  TelecomEngg CivilEngg  \
# 113          91.43  ...             -1              -1           -1        -1
# 115          76.17  ...             -1              -1           -1        -1
# 205          80.60  ...             -1              -1           -1        -1
# 290          89.42  ...             -1              -1           -1        -1
# 328          84.83  ...             -1              -1           -1        -1
# 432          86.88  ...             -1              -1           -1        -1
# 499          90.00  ...             -1              -1           -1        -1
# 603          71.00  ...             -1              -1           -1        -1
# 704          69.00  ...             -1              -1           -1        -1
# 723          74.00  ...             -1              -1           -1        -1
# 724          80.00  ...             -1              -1           -1        -1
# 765          89.00  ...             -1              -1           -1        -1
# 933          85.00  ...             -1              -1           -1        -1
# 976          85.40  ...             -1              -1           -1        -1
# 1059         60.10  ...             -1              -1           -1        -1
# 1300         80.50  ...             -1              -1           -1        -1
# 1494         83.00  ...             -1              -1           -1        -1
# 1618         74.50  ...             -1              -1           -1        -1
# 1653         76.00  ...             -1              -1           -1        -1
# 1743         73.60  ...             -1              -1           -1        -1
# 1896         89.60  ...             -1              -1           -1        -1
# 1926         70.60  ...             -1              -1           -1        -1
# 1949         75.00  ...             -1              -1           -1        -1
# 2040         87.40  ...             -1              -1           -1        -1
# 2118         61.40  ...             -1              -1           -1        -1
# 2298         82.00  ...             -1              -1           -1        -1
# 2391         85.20  ...             -1              -1           -1        -1
# 2472         84.00  ...             -1              -1           -1        -1
# 2577         85.17  ...             -1              -1           -1        -1
# 2722         94.24  ...             -1              -1           -1        -1
# 2728         74.00  ...             -1              -1           -1        -1
# 2739         75.77  ...             -1              -1           -1        -1
# 2878         76.60  ...             -1              -1           -1        -1
# 2898         86.00  ...             -1              -1           -1        -1
# 3286         78.20  ...             -1              -1           -1        -1
# 3357         89.00  ...             -1              -1           -1        -1
# 3396         88.40  ...             -1              -1           -1        -1
# 3511         75.40  ...             -1              -1           -1        -1
# 3653         79.80  ...             -1              -1           -1        -1
# 3746         91.68  ...             -1              -1           -1        -1
# 3778         87.20  ...             -1              -1           -1        -1
# 3795         70.80  ...             -1              -1           -1        -1
# 3829         83.80  ...             -1              -1           -1        -1
# 3881         80.40  ...             -1              -1           -1        -1
# 3917         93.00  ...             -1              -1           -1        -1
# 3959         89.60  ...             -1              -1           -1        -1
#
#       conscientiousness  agreeableness extraversion nueroticism  \
# 113              0.4155         0.3789      -0.1437    -0.74150
# 115              0.4155        -0.7866      -1.2196     1.16010
# 205             -2.0262        -0.7866       0.0100    -0.23440
# 290             -0.8772         0.2124      -1.5270     0.14590
# 328              0.7027         1.0449       1.5470    -1.62890
# 432              0.9900         0.3789       0.0100     1.28690
# 499              0.7027         0.7119       1.5470    -0.61470
# 603             -0.0154         0.0459       0.1637    -0.48790
# 704              0.5591         0.2124      -0.4511    -1.37530
# 723              0.2718         0.2124       1.5470    -1.12180
# 724              0.2318        -1.2153      -0.1988     0.37560
# 765             -0.6491         0.1888       0.6720    -0.43710
# 933              1.7081         0.8784       1.7007     0.14590
# 976             -2.0262         0.0459       0.4711    -0.99500
# 1059             1.7081         1.0449       0.9322     0.27270
# 1300             0.5591         0.0459       0.4711    -1.12180
# 1494             1.5644         1.5444       1.8543    -1.88240
# 1618             1.2772         0.7119       1.5470    -0.10760
# 1653            -0.5899         0.2124       0.4711    -0.74150
# 1743             0.5591         0.5454       0.0100     0.14590
# 1896             0.5591        -0.2871      -1.5270    -0.61470
# 1926             1.4208         1.2114       1.0859    -0.36120
# 1949             1.4208         0.2124       0.9322    -1.50210
# 2040            -1.0208         0.0459       0.0100     0.27270
# 2118             0.4155        -0.1206      -1.0659    -1.62890
# 2298             1.9011         1.9048      -0.7794    -1.58280
# 2391             0.8463         0.2124      -0.1437    -0.61470
# 2472            -1.5964         0.0875       2.5354    -0.53820
# 2577             0.2718         0.8784       0.1637     0.14590
# 2722            -0.4463         0.8784      -0.9122    -0.48790
# 2728            -1.5953         0.5454      -0.7585     0.52620
# 2739             1.7081         1.7109      -0.2974    -1.75560
# 2878            -1.0208        -0.2871      -0.9122     0.01920
# 2898             0.3941         0.0328      -1.9405    -0.43717
# 3286             0.4155         0.7119       0.7785    -2.38950
# 3357             1.1336         0.7119       0.7785     0.14590
# 3396            -0.3027         1.3779       1.0859    -0.61470
# 3511             1.2772        -0.7866      -1.0659    -1.24860
# 3653            -0.5899         0.0459       1.2396     0.27270
# 3746             0.8463         0.8784       1.7007    -2.00920
# 3778            -0.3027        -0.4536      -2.6028     0.77980
# 3795            -0.4463        -0.1206       1.0859     0.14590
# 3829            -0.1590         0.2124       0.0100     0.14590
# 3881            -0.3027         0.0459       0.3174    -1.12180
# 3917            -0.3027         0.5454      -0.6048    -1.62890
# 3959            -0.1590         0.7119       0.9322    -0.74150
#
#       openess_to_experience  avg_quality
# 113                 -0.2859    -0.075340
# 115                 -1.8189    -0.449900
# 205                 -1.0524    -0.817920
# 290                 -1.2440    -0.657980
# 328                 -0.6692     0.199300
# 432                  0.4805     0.629260
# 499                  1.0554     0.680460
# 603                  0.0973    -0.039280
# 704                  0.6721    -0.076560
# 723                  0.8637     0.354620
# 724                  0.3444    -0.092460
# 765                 -1.0774    -0.260560
# 933                  0.8637     1.059360
# 976                  0.2889    -0.443060
# 1059                 1.2470     1.040980
# 1300                -0.8608    -0.181300
# 1494                 1.0554     0.827220
# 1618                 1.0554     0.896780
# 1653                 0.2889    -0.071800
# 1743                -1.4356    -0.035040
# 1896                -2.0105    -0.776040
# 1926                 1.6302     0.997420
# 1949                 1.2470     0.462060
# 2040                 0.2889    -0.080660
# 2118                 0.4805    -0.383880
# 2298                -0.2875     0.231240
# 2391                 0.8637     0.232800
# 2472                -0.5081    -0.003960
# 2577                 1.2470     0.541360
# 2722                -0.8608    -0.365760
# 2728                -0.6692    -0.390280
# 2739                -0.0943     0.254340
# 2878                -2.0105    -0.842280
# 2898                -0.9194    -0.574034
# 3286                 0.6721     0.037700
# 3357                 0.4805     0.650080
# 3396                 0.2889     0.367060
# 3511                -0.0943    -0.383640
# 3653                -0.4776     0.098140
# 3746                 1.2470     0.532640
# 3778                 0.2889    -0.458080
# 3795                -0.8608    -0.039180
# 3829                -1.8189    -0.321920
# 3881                -0.0943    -0.231100
# 3917                 0.2889    -0.340420
# 3959                 0.2889     0.206500
#
# [46 rows x 40 columns]

# %%
df_18_1_19["Designation"].unique()
# Out:
# array(['software engineer'], dtype=object)

# %% [markdown]
# #The candidates choosing only software engineering, after the specialization computer science and engineering

# %%
df_18_1_19["Salary"].mean()
# Out:
# 348043.47826086957

# %% [markdown]
# #The Avg Salary of the candidates is 348043.47826086957 which is more than 3 Lakhs
# So the claim fails
# Let's check the claim after Jan 18, 2019

# %%
df18_1_19 = df[(df["DOJ"] >= "18/1/19 0:00") & (df["Specialization"] == "computer science & engineering") & (df["Designation"].isin(["programming analyst", "software engineer", "hardware engineer", "associate engineer"]))]

df18_1_19
# Out:
#      Unnamed: 0       ID    Salary          DOJ           DOL  \
# 31        train  1094324  340000.0  8/1/14 0:00   4/1/15 0:00
# 48        train   338428  390000.0  9/1/13 0:00       present
# 52        train   794209  400000.0  4/1/15 0:00       present
# 55        train   989860  250000.0  8/1/14 0:00       present
# 130       train   902366  325000.0  9/1/14 0:00       present
# ...         ...      ...       ...          ...           ...
# 3814      train   864107  145000.0  8/1/14 0:00       present
# 3818      train  1089624  240000.0  2/1/14 0:00       present
# 3939      train   716325  100000.0  7/1/13 0:00  12/1/14 0:00
# 3981      train  1077872  220000.0  9/1/14 0:00       present
# 3989      train  1204604  300000.0  9/1/14 0:00       present
#
#             Designation        JobCity Gender            DOB  10percentage  \
# 31    software engineer      Bangalore      m  10/23/92 0:00         77.20
# 48    software engineer      Bangalore      m   2/28/91 0:00         86.60
# 52    software engineer    Navi Mumbai      m    3/9/92 0:00         85.20
# 55    software engineer      Mangalore      m   2/13/92 0:00         90.80
# 130   software engineer  Greater Noida      m   1/10/92 0:00         82.80
# ...                 ...            ...    ...            ...           ...
# 3814  software engineer             -1      f    3/4/91 0:00         69.00
# 3818  software engineer         Mumbai      f    9/8/91 0:00         73.80
# 3939  software engineer      Hyderabad      m    7/5/92 0:00         65.00
# 3981  software engineer        Gurgaon      m  12/17/91 0:00         53.40
# 3989  software engineer      Bangalore      m  11/23/91 0:00         74.88
#
#       ... MechanicalEngg  ElectricalEngg  TelecomEngg CivilEngg  \
# 31    ...             -1              -1           -1        -1
# 48    ...             -1              -1           -1        -1
# 52    ...             -1              -1           -1        -1
# 55    ...             -1              -1           -1        -1
# 130   ...             -1              -1           -1        -1
# ...   ...            ...             ...          ...       ...
# 3814  ...             -1              -1           -1        -1
# 3818  ...             -1              -1           -1        -1
# 3939  ...             -1              -1           -1        -1
# 3981  ...             -1              -1           -1        -1
# 3989  ...             -1              -1           -1        -1
#
#       conscientiousness  agreeableness extraversion nueroticism  \
# 31              -0.0154         1.2114       1.0859    -1.50210
# 48              -2.5039         0.0328       0.3817     0.26793
# 52               1.1336         0.3789       1.0859     0.65300
# 55              -0.3027         0.7119      -0.2974     1.16010
# 130             -0.1590         0.0459       0.7785    -1.12180
# ...                 ...            ...          ...         ...
# 3814            -0.7335         0.7119       0.7785    -0.48790
# 3818             0.1282         0.5454       0.3174    -0.23440
# 3939            -0.3027        -1.9521      -0.6048     1.16010
# 3981             0.1282        -0.2871      -0.1437    -1.12180
# 3989             0.1282         0.0459       1.2396     1.03330
#
#       openess_to_experience  avg_quality
# 31                   0.2889     0.213740
# 48                   0.5024    -0.263814
# 52                   0.2889     0.708060
# 55                  -0.4776     0.158860
# 130                 -0.0943    -0.110140
# ...                     ...          ...
# 3814                 0.6721     0.188220
# 3818                -0.2859     0.094140
# 3939                -1.8189    -0.703680
# 3981                 1.4386     0.002840
# 3989                 0.6721     0.623820
#
# [95 rows x 40 columns]

# %%
df18_1_19["Designation"].unique()
# Out:
# array(['software engineer', 'associate engineer'], dtype=object)

# %% [markdown]
# The candidates choosing only software engineering and also associate engineering, after the specialization computer science and engineering

# %%
df18_1_19["Salary"].mean()
# Out:
# 325631.5789473684

# %% [markdown]
# The Avg Salary of the candidates is 325631.5789473684 which is also more than 3 Lakhs
